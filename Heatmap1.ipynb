# %% [markdown]
# <a href="https://colab.research.google.com/github/rohith033/AI-research/blob/main/Heatmap1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# path to the file having rainfall data
year = int(input())
df = pd.read_csv('/content/1935_rain.csv')
# Out:
# 1935

# %%
df.shape
# Out:
# (17415, 368)

# %%
df[0:100]
# Out:
#         X    Y       1       2       3       4       5       6       7  \
# 0   66.50  6.5 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 1   66.75  6.5 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 2   67.00  6.5 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 3   67.25  6.5 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 4   67.50  6.5 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# ..    ...  ...     ...     ...     ...     ...     ...     ...     ...
# 95  90.25  6.5 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 96  90.50  6.5 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 97  90.75  6.5 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 98  91.00  6.5 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 99  91.25  6.5 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
#
#          8  ...     357     358     359     360     361     362     363  \
# ...

# %%
import numpy as np

# %%
# cummalative value col
tmp=np.zeros(17415)
for i in range(1,366):
  tmp+=df[f'{i}']
df['cval']=tmp

# %%
print(df[1256:1257]['cval'])
# Out:
# 1256    1799.285121
# Name: cval, dtype: float64

# %%
df[0:5]
# Out:
#        X    Y       1       2       3       4       5       6       7       8  \
# 0  66.50  6.5 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 1  66.75  6.5 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 2  67.00  6.5 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 3  67.25  6.5 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 4  67.50  6.5 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
#
#    ...     358     359     360     361     362     363     364     365  \
# 0  ... -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 1  ... -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 2  ... -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 3  ... -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 4  ... -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
#
#    Unnamed: 367       cval
# 0           NaN -3649635.0
# ...

# %%
# for i in range(2,17415):
# print(df[1392:1393]['cval']==[-3649635.0])
# dir(df[][])
for i in range(0,17415):
  a = df._get_value(i,'cval')
  if(a==-3649635.0):
    df = df.drop([i])

# %%
df.head
# Out:
# <bound method NDFrame.head of            X      Y    1    2         3    4    5    6         7         8  \
# 987    77.00   8.25  0.0  0.0  0.000000  0.0  0.0  0.0  0.000000  0.000000
# 988    77.25   8.25  0.0  0.0  0.000000  0.0  0.0  0.0  0.000000  0.000000
# 989    77.50   8.25  0.0  0.0  0.000000  0.0  0.0  0.0  0.000000  4.044381
# 990    77.75   8.25  0.0  0.0  0.000000  0.0  0.0  0.0  1.072184  1.361382
# 1121   76.75   8.50  0.0  0.0  3.101929  0.0  0.0  0.0  0.000000  0.000000
# ...      ...    ...  ...  ...       ...  ...  ...  ...       ...       ...
# 16506  75.50  37.00  0.0  0.0  0.000000  0.0  0.0  0.0  0.000000  0.000000
# 16637  74.50  37.25  0.0  0.0  0.000000  0.0  0.0  0.0  0.000000  0.000000
# 16638  74.75  37.25  0.0  0.0  0.000000  0.0  0.0  0.0  0.000000  0.000000
# 16639  75.00  37.25  0.0  0.0  0.000000  0.0  0.0  0.0  0.000000  0.000000
# 16640  75.25  37.25  0.0  0.0  0.000000  0.0  0.0  0.0  0.000000  0.000000
#
# ...

# %%
import matplotlib.pyplot as plt
x = df['X']
y=df['Y']
plt.axis('off')
plt.scatter(x,y)

# %%
plt.axis('off')
plt.scatter(x,y,c=df['cval'], cmap='RdYlGn')
plt.savefig(f'indian_rainfall_{year}.png', bbox_inches='tight')
